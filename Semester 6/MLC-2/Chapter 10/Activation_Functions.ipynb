# %% [markdown]
# # 🔥 Final Activation Functions Notes
# Combined and cleaned from student + teacher notebooks.
#
# Includes classification, explanations, formulas, and code examples.

# %%
import numpy as np
x=np.array([0.5,0.2,0.1])
w=np.array([0.4,-0.7,0.2])
y_sum=np.dot(x,w)
output=y_sum
print("Weighted Sum :",y_sum)
print("Output",output)

# %%
def biological_neuron(signals,threshold=1.0):
    soma=sum(signals)
    if soma >=threshold:
        return 1  #neuron fires
    return 0
signals=[0.3,0.4,0.1]
print("Neuron output:",biological_neuron(signals))

# %%
#Activation Functions
import math
def identity(x):
    return x

def step(x):
    return 1 if x>=0 else 0

def threshold(x,theta=0.5):
    return 1 if x>=theta else 0

def relu(x):
    return max(0,x)

def sigmoid(x,k=1):
    return 1/(1+math.exp(-k*x))

def bipolar_sigmoid(x):
    return (2/(1+math.exp(-x)))-1

#hyperbolic tanget
def tan_h(x):
    return math.tanh(x)

# %%
# Input and Weights
x = np.array([0.5, 0.2, 0.1])
w = np.array([0.4, -0.7, 0.2])

# Weighted Sum
y_sum = np.dot(x, w)

print("Input Vector :", x)
print("Weight Vector:", w)
print("Weighted Sum :", y_sum)
print()

# Applying all activation functions in order
print("Identity Output        :", identity(y_sum))
print("Step Output            :", step(y_sum))
print("Threshold Output       :", threshold(y_sum))
print("ReLU Output            :", relu(y_sum))
print("Sigmoid Output         :", sigmoid(y_sum))
print("Bipolar Sigmoid Output :", bipolar_sigmoid(y_sum))
print("Tanh Output            :", tan_h(y_sum))

# %%
import numpy as np
def artificial_neuron(inputs,weights,bias=0):
    y_sum=np.dot(inputs,weights)+bias
    return y_sum
x=np.array([1,0,1])
w=np.array([0.5,-0.6,0.2])
print("SummationOutput: ",artificial_neuron(x,w,bias=0.1))

# %%
import numpy as np
import math

def identity(x):
    return x

def step(x):
    return 1 if x >= 0 else 0

def threshold(x, theta=0.5):
    return 1 if x >= theta else 0

def relu (x):
    return max(0, x)

def sigmoid(x, k=1):
    return 1 / (1 + math.exp(-k * x))

def bipolar_sigmoid(x):
    return (2 / (1 + math.exp(-x))) - 1

def tanh(x):
    return math.tanh(x)

values = [-2, -1, 0, 0,5, 1, 2]


x = np.array([0.5, 0.2, 0, 1])
w = np.array([0.4, -0.7, 0.2, 0]) # Added a fourth element to 'w' to match 'x'
y_sum = np.dot(x, w)

output = y_sum

output_relu = relu(y_sum)

output_sigmoid = sigmoid(y_sum)

output_tanh = tanh(y_sum)

output_step = step(y_sum)

output_threshold = threshold(y_sum)

output_bipolar_sigmoid = bipolar_sigmoid(y_sum)


print("Weighted Sum :", y_sum)
print("Output:", output)

print("Weighted Sum :", y_sum)
print("Output relu:", output_relu)

print("Weighted Sum :", y_sum)
print("Output sigmoid:", output_sigmoid)

print("Weighted Sum :",y_sum)
print("Output step:", output_step)

print("Weighted Sum :", y_sum)
print("Output threshold:", output_threshold)

print("Weighted Sum :", y_sum)
print("Output tanh:", output_tanh)

# %% [markdown]
# ## 📊 Activation Function Classification
# - **Linear**: Identity
# - **Binary**: Step Function
# - **Non‑Linear (Hidden Layers)**: Sigmoid, Tanh, ReLU, Leaky ReLU
# - **Output Layer (Multi‑class)**: Softmax
#
# ### Notes
# - Non-linear functions help neural networks learn complex patterns.
# - ReLU is commonly used due to efficiency.
# - Softmax is used for probability distribution in classification.
